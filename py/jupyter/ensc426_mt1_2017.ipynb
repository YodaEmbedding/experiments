# %%
# %load ~/dotfiles/root/usr/local/share/pythonstartup.py
import cmath
import functools
import itertools
import math
import os
import sys

from cmath import phase, polar
from functools import namedtuple, partial
from pprint import pprint
from time import time, sleep
from timeit import timeit

import cv2
import matplotlib.pyplot as plt
import numpy as np

from numpy import array, arange, concatenate, ones, ones_like, zeros, zeros_like
from numpy import exp, log, log2, log10, sqrt, ceil, floor
from numpy import pi, sin, cos, tan, arcsin, arccos, arctan, arctan2, degrees, radians
from scipy import optimize, signal
from scipy.constants import *

j = 1.j

np.set_printoptions(precision=3)

def E(x, precision=3):
    return ('{:.' + str(precision) + 'E}').format(x)

def print_reformat(x):
    return (
        "{:.3f}".format(x) if isinstance(x, float)   else
        "{:.3f}".format(x) if isinstance(x, complex) else
        "{:.3f}".format(x) if isinstance(x, np.complex128) else
        str(x))

def print(*args):
    __builtins__.print(*map(print_reformat, args))

def namestr(obj, namespace):
    return next(name for name in namespace if namespace[name] is obj)

def printn(*args, namespace=globals(), padding=20):
    for x in args:
        print(namestr(x, namespace).ljust(padding - 1),
            print_reformat(x).replace('\n', '\n' + ' ' * padding))

# %%
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt

# Constants
eta_0 = 376.73
c_0   = c

# %%
# Q1

f = 12e9
eps_r = 2.25
mu_r = 1.
a = 0.01
b = 0.02

c = c_0 / sqrt(eps_r * mu_r)

def fc(c, a, b, m, n):
    return c / (2*pi) * sqrt((m*pi/a)**2 + (n*pi/b)**2)

mn = np.mgrid[0:4, 0:4].reshape(2, -1).T
fc_mn = fc(c, a, b, mn[:, 0], mn[:, 1])

def hstack_multiline_str(s1, s2, padding=8):
    s1 = str(s1).splitlines()
    s2 = str(s2).splitlines()
    return '\n'.join(a.ljust(padding - 1) + b for a, b in zip(s1, s2))

cutoffs = hstack_multiline_str(mn, fc_mn[:, np.newaxis])

dominant = 1  # (m,n) = (0,1)
wc = fc_mn[dominant]
w  = 2 * pi * f 
beta = (j / c * sqrt(w**2 - wc**2)).imag
vp = w / beta

# eta = 
Z_TE = w * (mu_0 * mu_r) / beta

printn(c, cutoffs, beta, vp, Z_TE)

# %%
# Q2

R = 0
G = 0
L = 250e-9
C = 100e-12

f  = 2.5e9
Vg = 10
Rg = 100
l  = 0.01

Z_L = 50 + 50j

w     = 2 * pi * f
gamma = sqrt((R + j*w*L) * (G + j*w*C))
alpha = gamma.real
beta  = gamma.imag
lambd = 2 * pi / beta
Z_0   = sqrt((R + j*w*L) / (G + j*w*C))

R_L = (Z_L - Z_0) / (Z_L + Z_0)
Z_in = Z_0 * (Z_L + j*Z_0*tan(beta*l)) / (Z_0 + j*Z_L*tan(beta*l))
R_in = R_L * exp(2 * gamma * -l)

# S_0  =
# ??? see HW2 I guess
P_L = "TODO"

# TODO WTF is a generator and why haven't we used Vg and Rg???

printn(alpha, beta, lambd, Z_0, R_L, Z_in, R_in, P_L)

# %%
# Q3
